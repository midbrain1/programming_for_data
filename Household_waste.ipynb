# %%
import pandas as pd
waste_df = pd.read_csv('Data Sets/Household-Waste.csv')
waste_df
# Out:
#           Local Authority Generated (tonnes) Recycled (tonnes)  \
# 0           Aberdeen City             84,643            42,230
# 1           Aberdeenshire            122,830            54,018
# 2                   Angus             52,541            31,058
# 3         Argyll and Bute             46,901            18,101
# 4       City of Edinburgh            192,070            74,177
# 5        Clackmannanshire             25,473            14,125
# 6   Dumfries and Galloway             76,786            22,672
# 7             Dundee City             65,259            25,074
# 8           East Ayrshire             55,097            29,300
# 9     East Dunbartonshire             52,692            29,145
# 10           East Lothian             49,979            27,644
# 11      East Renfrewshire             48,609            32,953
# 12                Falkirk             70,032            37,134
# 13                   Fife            174,977            77,856
# ...

# %%
Local_Waste=waste_df[['Local Authority','Carbon Impact (TCO2e)']]
Local_Waste
# Out:
#           Local Authority Carbon Impact (TCO2e)
# 0           Aberdeen City               180,260
# 1           Aberdeenshire               310,947
# 2                   Angus               100,813
# 3         Argyll and Bute               117,899
# 4       City of Edinburgh               471,188
# 5        Clackmannanshire                53,323
# 6   Dumfries and Galloway               209,440
# 7             Dundee City               149,839
# 8           East Ayrshire               119,102
# 9     East Dunbartonshire               110,998
# 10           East Lothian               106,233
# 11      East Renfrewshire                94,538
# 12                Falkirk               153,946
# 13                   Fife               387,425
# 14           Glasgow City               744,090
# 15               Highland               297,898
# 16             Inverclyde                58,006
# 17             Midlothian                91,551
# 18                  Moray                87,796
# ...

# %%
Local_Waste['Carbon Impact (TCO2e)'] = int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f8a8dac4b498> in <module>
# ----> 1 int(Local_Waste['Carbon Impact (TCO2e)'])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     110         if len(self) == 1:
#     111             return converter(self.iloc[0])
# --> 112         raise TypeError(f"cannot convert the series to {converter}")
#     113
#     114     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
Local_Waste['Carbon Impact (TCO2e)'] = int(Local_Waste['Carbon Impact (TCO2e)'])
Local_Waste
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-55d26e5a6fb5> in <module>
# ----> 1 Local_Waste['Carbon Impact (TCO2e)'] = int(Local_Waste['Carbon Impact (TCO2e)'])
#       2 Local_Waste
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     110         if len(self) == 1:
#     111             return converter(self.iloc[0])
# --> 112         raise TypeError(f"cannot convert the series to {converter}")
#     113
#     114     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>
